# %% [markdown]
# - 3 type of load balancers
#    1. application load balancers
#    2. Network load balancers
#    3. classic load balancers

# %% [markdown]
# ![](screenshots/load_balancer.png)

# %% [markdown]
# ____

# %% [markdown]
# ### components
# - client ->  target_group((apache)ec2_instances)   ->

# %% [markdown]
# ![](screenshots/1_load.png)

# %% [markdown]
# - LOAD BALANCING -> Target Groups-> create target group ->

# %% [markdown]
# -
#   - Target group name:
#   - Target type:
#   - Protocol:
#   - Port:
#   - VPC:
# - Health check settings
#
#   - Protocol
#   - Path
# - Advanced health check settings

# %% [markdown]
# ![](screenshots/2_load.png)

# %% [markdown]
# - Targets
#    - edit -> select instances -> add to registered -> save

# %% [markdown]
# ![](screenshots/3_load.png)

# %% [markdown]
# - Create load balancer
#   - Application load balancer(http,https) ->create
#     - Name : Load balancer 1
#     - scheme : internet facing | internal
#     - ip address type :
#   - Listners
#     - HTTP - PORT 80
#   - Availability zones
#   - configure security groups
#   - configure routing
