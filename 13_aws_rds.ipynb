# %% [markdown]
# - relational data base serivices
#   - mysql

# %% [markdown]
# ___

# %% [markdown]
# - easy to administer
# - highly scalable
# - available and durable
# - fast
# - secure
# - inexpensive

# %% [markdown]
# ___

# %% [markdown]
# - RDS
#    - create database
#      - MySQL
#      - templates -> free tyre
#      - db instance identifier
#      - burstable classes
#      - storage types: general purpose
#      - allocated storage:20
#      - connectivity
#      - vpc
#      - additional connectivity
#      - security group
#      - password authentication
#     -
#     -
#     - create database

# %% [markdown]
# ____

# %% [markdown]
#  - Connecting to DB form EC2
#   - End Point
#   - DB Port
#   - Username
#   - Password

# %% [markdown]
# ___
# - in ec2 shell install install mysql client
