# %% [markdown]
# - Boto3 is the official Python SDK (software development kit) for Amazon Web Services (AWS). It lets you write Python code that interacts with AWS services like S3, EC2, DynamoDB, Lambda, and many more.
